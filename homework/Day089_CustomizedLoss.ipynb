# %% [markdown]
# ## 範例重點
# * 學習如何在 keras 中撰寫自定義的 loss function
# * 知道如何在訓練時使用自定義的 loss function

# %%
import os
import keras

# 本範例不需使用 GPU, 將 GPU 設定為 "無"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# 資料前處理 -Y 轉成 onehot
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
import tensorflow as tf
import keras.backend as K

"""
# 撰寫自定義的 loss function: focal loss (https://blog.csdn.net/u014380165/article/details/77019084)
"""
def focal_loss(gamma=2., alpha=4.):
    gamma = float(gamma)
    alpha = float(alpha)
    def focal_loss_fixed(y_true, y_pred):
        """Focal loss for multi-classification
        FL(p_t)=-alpha(1-p_t)^{gamma}ln(p_t)
        """
        epsilon = 1e-8
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)

        model_out = tf.add(y_pred, epsilon)
        ce = tf.multiply(y_true, -tf.log(model_out))
        weight = tf.multiply(y_true, tf.pow(tf.subtract(1., model_out), gamma))
        fl = tf.multiply(alpha, tf.multiply(weight, ce))
        reduced_fl = tf.reduce_max(fl, axis=1)
        return tf.reduce_mean(reduced_fl)
    return focal_loss_fixed

# %%
"""
# 載入 Callbacks，撰寫一個 f1 score 的 callback function
"""

from keras.callbacks import Callback
from sklearn.metrics import f1_score

class f1sc(Callback):
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        print(logs)
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        print("default marams metrics", self.params['metrics'])
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        logs["val_f1sc"] = f1_score(y_true = y_true, y_pred = y_pred, average="weighted")
        
log_f1sc = f1sc()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
"""
# 在 compile 時，使用自定義的 loss function
"""
model.compile(loss=focal_loss(), metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[log_f1sc]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]

valid_f1sc = model.history.history['val_f1sc']
# Out:
# WARNING:tensorflow:From /Users/ctling/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# WARNING:tensorflow:From /Users/ctling/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/ctling/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 50000 samples, validate on 10000 samples
# {}
# default marams metrics ['loss', 'acc', 'val_loss', 'val_acc']
# Epoch 1/50
# 50000/50000 [==============================] - 11s 217us/step - loss: 6.0745 - acc: 0.3287 - val_loss: 5.9304 - val_acc: 0.3601
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.0560625139048484
# Epoch 2/50
#  1024/50000 [..............................] - ETA: 6s - loss: 4.5846 - acc: 0.4131
# /Users/ctling/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 50000/50000 [==============================] - 9s 175us/step - loss: 4.4210 - acc: 0.4417 - val_loss: 4.8248 - val_acc: 0.3992
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.05459835124798002
# Epoch 3/50
# 50000/50000 [==============================] - 10s 204us/step - loss: 3.9914 - acc: 0.4836 - val_loss: 4.3623 - val_acc: 0.4469
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.06382898825185093
# Epoch 4/50
# 50000/50000 [==============================] - 9s 174us/step - loss: 3.7204 - acc: 0.5103 - val_loss: 4.3400 - val_acc: 0.4382
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.06238322004879951
# Epoch 5/50
# 50000/50000 [==============================] - 9s 189us/step - loss: 3.4948 - acc: 0.5313 - val_loss: 4.1785 - val_acc: 0.4556
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.058242792482698306
# Epoch 6/50
# 50000/50000 [==============================] - 11s 215us/step - loss: 3.3093 - acc: 0.5490 - val_loss: 4.1655 - val_acc: 0.4548
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.05707996127229429
# Epoch 7/50
# 50000/50000 [==============================] - 9s 185us/step - loss: 3.1363 - acc: 0.5697 - val_loss: 4.0441 - val_acc: 0.4694
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07275503925934608
# Epoch 8/50
# 50000/50000 [==============================] - 10s 205us/step - loss: 2.9849 - acc: 0.5818 - val_loss: 3.9178 - val_acc: 0.4819
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.06698713013372148
# Epoch 9/50
# 50000/50000 [==============================] - 10s 202us/step - loss: 2.8399 - acc: 0.5980 - val_loss: 4.0038 - val_acc: 0.4666
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.06906664811933051
# Epoch 10/50
# 50000/50000 [==============================] - 8s 168us/step - loss: 2.6956 - acc: 0.6126 - val_loss: 3.9392 - val_acc: 0.4816
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07139498930967943
# Epoch 11/50
# 50000/50000 [==============================] - 10s 206us/step - loss: 2.5563 - acc: 0.6274 - val_loss: 3.8836 - val_acc: 0.4848
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.05914653816350897
# Epoch 12/50
# 50000/50000 [==============================] - 11s 217us/step - loss: 2.4275 - acc: 0.6429 - val_loss: 3.9855 - val_acc: 0.4734
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.06313101903695408
# Epoch 13/50
# 50000/50000 [==============================] - 11s 222us/step - loss: 2.3019 - acc: 0.6572 - val_loss: 3.9443 - val_acc: 0.4866
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07182148025058718
# Epoch 34/50
# 50000/50000 [==============================] - 11s 217us/step - loss: 0.4439 - acc: 0.9235 - val_loss: 5.4569 - val_acc: 0.4788
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07683862847464976
# Epoch 35/50
# 50000/50000 [==============================] - 12s 237us/step - loss: 0.4022 - acc: 0.9324 - val_loss: 5.4391 - val_acc: 0.4774
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07560185818482264
# Epoch 36/50
# 50000/50000 [==============================] - 11s 221us/step - loss: 0.3569 - acc: 0.9408 - val_loss: 5.4734 - val_acc: 0.4878
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07532437920900663
# Epoch 37/50
# 50000/50000 [==============================] - 9s 190us/step - loss: 0.3216 - acc: 0.9485 - val_loss: 5.5235 - val_acc: 0.4802
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07573598284498759
# Epoch 38/50
# 50000/50000 [==============================] - 10s 199us/step - loss: 0.2877 - acc: 0.9541 - val_loss: 5.6372 - val_acc: 0.4780
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07596751292111437
# Epoch 39/50
# 50000/50000 [==============================] - 10s 204us/step - loss: 0.2620 - acc: 0.9582 - val_loss: 5.6641 - val_acc: 0.4845
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07445958359166187
# Epoch 40/50
# 50000/50000 [==============================] - 12s 239us/step - loss: 0.2305 - acc: 0.9655 - val_loss: 5.8170 - val_acc: 0.4723
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.076395939714717
# Epoch 41/50
# 50000/50000 [==============================] - 13s 259us/step - loss: 0.2114 - acc: 0.9686 - val_loss: 5.7736 - val_acc: 0.4818
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07317506382787801
# Epoch 42/50
# 50000/50000 [==============================] - 9s 183us/step - loss: 0.1906 - acc: 0.9737 - val_loss: 5.8911 - val_acc: 0.4753
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.0709830741106661
# Epoch 43/50
# 50000/50000 [==============================] - 10s 191us/step - loss: 0.1713 - acc: 0.9770 - val_loss: 6.0492 - val_acc: 0.4748
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07395107839115697
# Epoch 44/50
# 50000/50000 [==============================] - 11s 219us/step - loss: 0.1521 - acc: 0.9815 - val_loss: 6.0369 - val_acc: 0.4835
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.075236679102541
# Epoch 45/50
# 50000/50000 [==============================] - 10s 193us/step - loss: 0.1341 - acc: 0.9845 - val_loss: 6.1476 - val_acc: 0.4784
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07597664560774428
# Epoch 46/50
# 50000/50000 [==============================] - 9s 176us/step - loss: 0.1195 - acc: 0.9872 - val_loss: 6.1392 - val_acc: 0.4840
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07525830639894093
# Epoch 47/50
# 50000/50000 [==============================] - 11s 213us/step - loss: 0.1114 - acc: 0.9891 - val_loss: 6.2803 - val_acc: 0.4809
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07473227230352888
# Epoch 48/50
# 50000/50000 [==============================] - 9s 172us/step - loss: 0.1067 - acc: 0.9897 - val_loss: 6.4142 - val_acc: 0.4728
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07538877970849336
# Epoch 49/50
# 50000/50000 [==============================] - 9s 179us/step - loss: 0.0911 - acc: 0.9919 - val_loss: 6.3595 - val_acc: 0.4772
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07542123456790124
# Epoch 50/50
# 50000/50000 [==============================] - 10s 206us/step - loss: 0.0827 - acc: 0.9935 - val_loss: 6.3715 - val_acc: 0.4824
# ['loss', 'acc', 'val_loss', 'val_acc', 'val_auc', 'val_f1sc', 'val_fp', 'val_fn', 'val_tp', 'val_tn']
# validation f1-score: 0.07528024238692341

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
plt.plot(range(len(model.history.history['val_f1sc'])), train_acc, label="validation f1-score")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# ## Work
# 1. 請自行定義一個 loss function, 為 0.3 * focal loss + 0.7 cross-entropy，訓練並比較結果
